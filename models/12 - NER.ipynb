# %% [markdown]
# O NER (Named Entity Recognition) é uma tarefa de Processamento de Linguagem Natural cujo objetivo é identificar e classificar automaticamente “entidades nomeadas” em um texto.
#
# Essas entidades são palavras ou expressões que representam objetos do mundo real, como:
#
# - Pessoas
# - Locais
# - Organizações
# - Datas
# - Valores
# - Produtos, eventos etc.
#
# Exemplo:
#
# “A Apple lançou o iPhone 15 em setembro de 2023 nos Estados Unidos.”
#
# → O modelo NER pode reconhecer:
#
# - Apple → ORGANIZAÇÃO
# - iPhone 15 → PRODUTO
# - setembro de 2023 → DATA
# - Estados Unidos → LOCAL

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (0.20.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.3.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.12.4)
# Requirement already satisfied: jinja2 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\luirys silva\appdata\roaming\python\python311\site-packages (from spacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\luirys silva\appdata\roaming\python\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.10.5)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\luirys silva\appdata\roaming\python\python311\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.2.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\luirys silva\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: wrapt in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (2.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\luirys silva\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import en_core_web_sm
import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import en_core_web_sm
#       2 import spacy
#       3 nlp = spacy.load("en_core_web_sm")
#
# ModuleNotFoundError: No module named 'en_core_web_sm'

# %%
import random
from spacy import util
from spacy.tokens import Doc
from spacy.training import Example
from spacy.language import Language
from spacy import displacy

def customizing_pipeline_component(nlp: Language):
    train_data = [
        ('Apple is releasing a new iPhone next month', [(0, 5, "BRAND"), (25, 31, "PRODUCT"), (32, 42,"DATE")]),
        ("Nike is the world's leading sportswear brand", [(0, 4, "BRAND")]),
        ("Coca-Cola's revenue has increased by 5% this year", [(0, 10, "BRAND")]),
        #("Estamos no E-info, melhor evento de Informática, com Luirys o melhor professor.",[(11, 17, "EVENT"), (48, 54, "PERSON")])
    ]

    # Result before training
    print(f"\nResult BEFORE training:")
    doc = nlp(u'Steve Jobs was fired by Apple.')
    displacy.render(doc, style="ent", jupyter=True)

    # Disable all pipe components except 'ner'
    #disabled_pipes = []
    #for pipe_name in nlp.pipe_names:
    #    if pipe_name != 'ner':
    #        nlp.disable_pipes(pipe_name)
    #        disabled_pipes.append(pipe_name)

    print("   Training ...")
    optimizer = nlp.create_optimizer()
    for _ in range(25):
        random.shuffle(train_data)
        for raw_text, entity_offsets in train_data:
            doc = nlp.make_doc(raw_text)
            example = Example.from_dict(doc, {"entities": entity_offsets})
            nlp.update([example], sgd=optimizer)

    # Enable all previously disabled pipe components
    #for pipe_name in disabled_pipes:
    #    nlp.enable_pipe(pipe_name)

    # Result after training
    print(f"Result AFTER training:")
    doc = nlp(u'Steve Jobs was fired by Apple')
    displacy.render(doc, style="ent", jupyter=True)

def main():
    nlp = spacy.load('en_core_web_sm')
    customizing_pipeline_component(nlp)


if __name__ == '__main__':
    main()
# Out:
# Result BEFORE training:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steve Jobs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was fired by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>
#    Training ...
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Coca-Cola's revenue has increased by 5% this year" with entities "[(0, 10, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Result AFTER training:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steve Jobs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was fired by
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BRAND</span>
# </mark>
# </div></span>
